# %%
import numpy as np
import pandas as pd

# %%
# importing sample of global supertore dataset
df = pd.read_csv('https://raw.githubusercontent.com/yannie28/Global-Superstore/master/Global_Superstore_100.csv')
df.head(3)
# Out:
#    Row ID                  Order ID  Order Date   Ship Date       Ship Mode  \
# 0   20685   IN-2015-BT1168066-42351  2015-12-13  2015-12-19  Standard Class
# 1   18072   ES-2015-AB1016545-42351  2015-12-13  2015-12-18    Second Class
# 2   40506  CA-2015-RS19870140-42350  2015-12-12  2015-12-15    Second Class
#
#     Customer ID   Customer Name      Segment  Postal Code        City  ...  \
# 0    BT-1168066  Brian Thompson     Consumer          NaN         Ube  ...
# 1    AB-1016545     Alan Barnes     Consumer          NaN    Grenoble  ...
# 2  RS-198701402      Roy Skaria  Home Office      52601.0  Burlington  ...
#
#     Product ID         Category Sub-Category                  Product Name  \
# 0  OFF-AP-4508  Office Supplies   Appliances   Hamilton Beach Stove, White
# 1  TEC-PH-3148       Technology       Phones  Apple Smart Phone, Full Size
# 2  OFF-EN-5580  Office Supplies    Envelopes         Pastel Pink Envelopes
#
# ...

# %% [markdown]
# ## Assign method to create new columns to the dataframe
#
# Note: assign creates a copy of the dataset, and changes on newdf doesn't effect df ie .copy() applied by default.
# Can create multiple columns at once
# Useful for method chaining

# %%
new_df = df.assign(month_order_date = lambda x:pd.to_datetime(x['Order Date']).dt.month,
                   year_order_date = lambda x:pd.to_datetime(x['Order Date']).dt.year,
                   msp = df['Sales']/df['Discount'],
                   msp_final = lambda x: np.where(x['msp']==np.inf,x['Sales'],x['msp']),
                   unit_price = lambda x:np.round(x['msp_final']/x['Quantity'],2),
                   ).drop(columns=['msp']).rename(columns={'msp_final':'msp'})

# %%
new_df.sample(4)
# Out:
#     Row ID                  Order ID  Order Date   Ship Date       Ship Mode  \
# 93   48715    EG-2014-LS694538-41667  2014-01-28  2014-01-31     First Class
# 55    8148   MX-2014-DB1321036-41961  2014-11-18  2014-11-20     First Class
# 17   12449  ES-2015-MS17770139-42275  2015-09-28  2015-10-01     First Class
# 41   14222  ES-2015-MP17470120-42101  2015-04-07  2015-04-11  Standard Class
#
#     Customer ID     Customer Name      Segment  Postal Code        City  ...  \
# 93    LS-694538  Linda Southworth    Corporate          NaN  Alexandria  ...
# 55   DB-1321036       Dean Braden     Consumer          NaN   La Romana  ...
# 17  MS-17770139  Maxwell Schwartz     Consumer          NaN     Burnley  ...
# 41  MP-17470120       Mark Packer  Home Office          NaN      Madrid  ...
#
#       Sales Quantity Discount   Profit Shipping Cost Order Priority  \
# 93    30.48        4      0.0    13.68         9.380       Critical
# ...
